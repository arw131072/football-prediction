# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print(PROJECT_ROOT)
# Out:
# d:\ARW-files\projects\football-prediction

# %%
from src.ratings.classic import ClassicElo
from src.ratings.fifa import FIFASUM
from src.ratings.fifa_home import FIFASUMHome

# %%
import src

print(src.__file__)
# Out:
# d:\ARW-files\projects\football-prediction\src\__init__.py

# %%
import os
import sys

print("cwd =", os.getcwd())

print("\nFirst 10 paths:")
for p in sys.path[:10]:
    print(p)
# Out:
# cwd = d:\ARW-files\projects\football-prediction\notebooks
#
# First 10 paths:
# c:\Users\ARW\anaconda3\envs\prediction\python312.zip
# c:\Users\ARW\anaconda3\envs\prediction\DLLs
# c:\Users\ARW\anaconda3\envs\prediction\Lib
# c:\Users\ARW\anaconda3\envs\prediction
#
# c:\Users\ARW\anaconda3\envs\prediction\Lib\site-packages
# c:\Users\ARW\anaconda3\envs\prediction\Lib\site-packages\win32
# c:\Users\ARW\anaconda3\envs\prediction\Lib\site-packages\win32\lib
# c:\Users\ARW\anaconda3\envs\prediction\Lib\site-packages\pythonwin

# %%
classic = ClassicElo()
fifa = FIFASUM()
fifa_home = FIFASUMHome()

# %%
classic_df = classic.fit_transform(df_results)

fifa_df = fifa.fit_transform(df_results)

fifa_home_df = fifa_home.fit_transform(df_results)

# %%
classic_df[
    [
        "home_rating",
        "away_rating",
        "rating_diff"
    ]
].head()

# %%
final_ratings = {}

for team in df["home_team"].unique():
    pass
